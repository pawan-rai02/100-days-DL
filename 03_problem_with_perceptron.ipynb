# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['inp1'] = [1, 1, 0, 0]
or_data['inp2'] = [1, 0, 1, 0]
or_data['output'] = [1, 1, 1, 0]

# %%
and_data['inp1'] = [1, 1, 0, 0]
and_data['inp2'] = [1, 0, 1, 0]
and_data['output'] = [1, 0, 0, 0]

# %%
xor_data['inp1'] = [1, 1, 0, 0]
xor_data['inp2'] = [1, 0, 1, 0]
xor_data['output'] = [0, 1, 1, 0]

# %%
and_data
# Out:
#    inp1  inp2  output
# 0     1     1       1
# 1     1     0       0
# 2     0     1       0
# 3     0     0       0

# %%
sns.scatterplot(x = and_data['inp1'], y = and_data['inp2'], hue= and_data['output'], s = 200)
# Out:
# <Axes: xlabel='inp1', ylabel='inp2'>

# %%
or_data
# Out:
#    inp1  inp2  output
# 0     1     1       1
# 1     1     0       1
# 2     0     1       1
# 3     0     0       0

# %%
xor_data
# Out:
#    inp1  inp2  output
# 0     1     1       0
# 1     1     0       1
# 2     0     1       1
# 3     0     0       0

# %%
from sklearn.linear_model import Perceptron

clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:, :2].values, and_data.iloc[:, -1].values)
clf2.fit(or_data.iloc[:, :2].values, or_data.iloc[:, -1].values)
clf3.fit(xor_data.iloc[:, :2].values, xor_data.iloc[:, -1].values)
# Out:
# Perceptron()

# %%
print('and data coef', clf1.coef_)
print('and data intercept', clf1.intercept_)
# Out:
# and data coef [[2. 2.]]
# and data intercept [-2.]

# %%
print('or data coef', clf2.coef_)
print('or data intercept', clf2.intercept_)
# Out:
# or data coef [[2. 2.]]
# or data intercept [-1.]

# %%
print('xor data coef', clf3.coef_)
print('xor data intercept', clf3.intercept_)
# Out:
# xor data coef [[0. 0.]]
# xor data intercept [0.]

# %%
x = np.linspace(-1, 1, 5)

y = -x + 1

# %%
plt.plot(x, y)
sns.scatterplot(x = and_data['inp1'], y = and_data['inp2'], hue= and_data['output'])
# Out:
# <Axes: xlabel='inp1', ylabel='inp2'>

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(xor_data.iloc[:, 0:2].values, xor_data.iloc[:, -1].values, clf = clf3, legend = 2)
# Out:
# <Axes: >
